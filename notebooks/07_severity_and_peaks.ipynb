# %% [markdown]
# # 07 - COVID-19 Severity and Peaks
#
# Which countries suffered the most severe peaks (deaths, cases, etc,)? (In relation to their population).
#
# We are going to analyze:
#
# * Maximum peak of cases per capita.
# * Speed of growth ($\Delta cases / time$)

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# ## Load Data

# %% [markdown]
# ## Geographical Analysis
