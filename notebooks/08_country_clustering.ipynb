# %% [markdown]
# # 07 - COVID-19 Country clustering
#
# Which countries performed similarly during the pandemic?
#
# We are going to analyze:
#
# * Maximum peak of cases per capita.
# * Speed of growth ($\Delta cases / time$)

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# ## Load Data

# %% [markdown]
# ## Geographical Analysis
